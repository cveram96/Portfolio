# %%
# Install the ultralytics library if it's not already installed.
# %pip install ultralytics

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo26n.pt")  # load an official model


# Predict with the model
results = model(r"C:\Users\ChristianV\Documents\GitHub\Portfolio\Files\YOLO_TEST\juldar.jpg", save=True)

# Access the results
for result in results:
    xywh = result.boxes.xywh  # center-x, center-y, width, height
    xywhn = result.boxes.xywhn  # normalized
    xyxy = result.boxes.xyxy  # top-left-x, top-left-y, bottom-right-x, bottom-right-y
    xyxyn = result.boxes.xyxyn  # normalized
    names = [result.names[cls.item()] for cls in result.boxes.cls.int()]  # class name of each box
    confs = result.boxes.conf  # confidence score of each box
# Out:
# image 1/1 C:\Users\ChristianV\Documents\GitHub\Portfolio\Files\YOLO_TEST\juldar.jpg: 640x640 2 persons, 52.0ms
# Speed: 1.4ms preprocess, 52.0ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to C:\Users\ChristianV\Documents\GitHub\Portfolio\Files\YOLO_TEST\runs\detect\predict-2
